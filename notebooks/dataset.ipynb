# %%
import pandas as pd
import sys
import os
sys.path.append('../tools')
import dataset as ds
import sqlalchemy as alch
import dotenv
import sqltools as st

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
friends = pd.read_csv("../data/friends_quotes.csv",encoding = "utf-8")

# %%
friends.rename({"author":"character"}, axis=1, inplace=True)
friends.drop("quote_order",axis=1,inplace = True)

# %%
friends.columns
# Out:
# Index(['character', 'episode_number', 'episode_title', 'quote', 'season'], dtype='object')

# %%
friends.quote = friends.quote.str.replace("","`",regex = True)
friends.quote = friends.quote.str.replace("''","`",regex = True)
friends.episode_title = friends.episode_title.str.replace("","`",regex = True)
friends.episode_title = friends.episode_title.str.replace("'","`",regex = True)

# %%
friends["episode_number"] = friends.episode_number.astype('int64')
friends["season"] = friends.season.astype('int64')
friends["character"] = friends.character.str.title()

# %%
friends.character = friends.character.str.replace("Mnca","Monica")
friends.character = friends.character.str.replace(r"(Rach.?$)","Rachel",regex = True)
friends.character = friends.character.str.replace(r"(Chan.?$)","Chandler",regex = True)
friends.character = friends.character.str.replace(r"(Phoe.?$)","Phoebe",regex = True)
friends.character = friends.character.str.replace("Fat Monica","Monica",regex = True)
friends.character = friends.character.str.replace("Joey/Drake","Joey",regex = True)
friends.character = friends.character.str.replace("Big Nosed Rachel","Rachel",regex = True)
friends.character = friends.character.str.replace("Fat Joey","Joey",regex = True)

# %%
cuenta = friends.groupby("character").agg({"quote":"count"}).reset_index().sort_values("quote",ascending = False)[:6]

# %%
personajes = list(cuenta.character.values)

# %%
personajes
# Out:
# ['Rachel', 'Ross', 'Monica', 'Chandler', 'Joey', 'Phoebe']

# %%
principales = friends.loc[friends['character'].isin(personajes)]

# %%
principales.to_csv("../data/principales.csv",index=False)

# %%
muestra = principales.sample(200)

# %%
muestra.to_csv("../data/muestra.csv",index=False)

# %%
muestra.columns
# Out:
# Index(['character', 'episode_number', 'episode_title', 'quote', 'season'], dtype='object')

# %%
muestra.sample(10)
# Out:
#       character  episode_number       episode_title  \
# 25270      Joey               7       Ross Moves In
# 31561  Chandler               7         Phoebe Runs
# 58317    Rachel              12    Phoebe`s Wedding
# 53907      Joey              21  The Fertility Test
# 10210      Joey              19      Eddie Won`t Go
# 44201    Rachel               5       Rachel`s Date
# 1765       Ross               8     Nana Dies Twice
# 12560      Ross               5           Frank Jr.
# 28824      Ross              21            The Ball
# 4249     Monica              18       All The Poker
#
#                                                    quote  season
# 25270                                              Okay.       5
# 31561                           Hey Mon, how's it going?       6
# 58317                                      Hey Pheebs...      10
# 53907  Ok, let me stop you right there. The Mets suck...       9
# 10210                     I fell down an elevator shaft.       2
# 44201  I made the mistake of telling him that I was p...       8
# 1765   (to Joey) So he's calling from Rome. I could d...       1
# 12560  Well I-I-I, that kind of thing requires some s...       3
# 28824  Wow! We are pretty good at this! Hey! We total...       5
# 4249             Oh, please, that is such a lame excuse!       1

# %%
# for i,r in muestra.iterrows():
#     #insert (r.character)
#     print(r.season)

# %%
tempo = list(muestra.season.unique())

# %%
type(tempo)
# Out:
# list

# %%
passw = os.getenv("pass_sql")
dbName = 'friends'
connectionData = f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %%
for i,r in muestra.iterrows():
    col = "season"
    st.insertTemp(col,r.season)

# %%
for i,r in muestra.iterrows():
    col = "character"
    st.insertCar(col,r.character)

# %%
for i,r in muestra.iterrows():
    col = "episode_title"
    value = r.episode_title
    num = r.episode_number
    tempo = r.season
    st.insertEp(col,value,num,tempo)

# %%
for t in tempo:
    print(t)
    lista = []
    cosa = list(engine.execute(f"SELECT numero,tituloEP,idTemporadas FROM episodios WHERE idTemporadas ={t};"))
    lista.append(cosa)
# Out:
# 4
# 3
# 1
# 5
# 9
# 8
# 6
# 7
# 2
# 10

# %%
cosa[0]
# Out:
# (12, 'Phoebe`s Wedding', 10)

# %%
for i,r in muestra.iterrows():
    print(r.character)

# %%
for i,r in muestra.iterrows():
    value = r.character
    print(engine.execute(f"SELECT idcharacters FROM characters WHERE nombre ='{value}';"))
    print(list(engine.execute(f"SELECT idcharacters FROM characters WHERE nombre ='{value}';")))
    print(list(engine.execute(f"SELECT idcharacters FROM characters WHERE nombre ='{value}';"))[0])
    print(list(engine.execute(f"SELECT idcharacters FROM characters WHERE nombre ='{value}';"))[0][0])
# Out:
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da5e0>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e294f0>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e294f0>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a310>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e294f0>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a3d0>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a670>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da700>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568dad30>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da700>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e294f0>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a670>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da700>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e294f0>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a310>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e294f0>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da5e0>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da5e0>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568dad30>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a670>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e295e0>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e295e0>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a670>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e294f0>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a670>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a670>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a3d0>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a310>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a670>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a3d0>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a310>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f82e0>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da5e0>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f8790>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f8790>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e299d0>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f8a60>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568da700>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f8fd0>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a310>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f86d0>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568dad30>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f86a0>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0855e295e0>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568f8a60>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df40>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0857129970>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f085694df70>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7a310>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(2,)]
# (2,)
# 2
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(5,)]
# (5,)
# 5
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(6,)]
# (6,)
# 6
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(1,)]
# (1,)
# 1
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(4,)]
# (4,)
# 4
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f0885f7ac40>
# [(3,)]
# (3,)
# 3
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7f08568df070>
# [(1,)]
# (1,)
# 1
